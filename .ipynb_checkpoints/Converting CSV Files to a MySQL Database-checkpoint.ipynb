# %% [markdown]
# # Way 1

# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# 📌 إعداد الاتصال مع MySQL
# عدل USER, PASSWORD, HOST, DBNAME حسب معلوماتك
engine = create_engine("mysql+pymysql://root:@localhost/bike_1")

# 📂 مجلد الملفات
folder_path = "./"   # إذا الملفات بنفس المجلد مع الكود

# 📌 قائمة الملفات اللي بدنا نستوردها
files = [
       "brands.csv",
        "categories.csv",
        "products.csv",
        "stores.csv",
        "customers.csv",
        "staffs.csv",
        "orders.csv",
        "stocks.csv",
        "order_items.csv"
]

# 🟢 استيراد كل ملف وتحويله لجدول
for file in files:
    table_name = file.split(".")[0]   # اسم الجدول = اسم الملف بدون .csv
    print(f"📥 Importing {file} → Table: {table_name}")

    # اقرأ الملف
    df = pd.read_csv(os.path.join(folder_path, file), encoding="utf-8")

    # خزن البيانات بالجدول
    df.to_sql(table_name, con=engine, if_exists="append", index=False)

print("✅ كل الملفات اتخزنت في MySQL بنجاح")
# Out:
# 📥 Importing brands.csv → Table: brands
# 📥 Importing categories.csv → Table: categories
# 📥 Importing products.csv → Table: products
# 📥 Importing stores.csv → Table: stores
# 📥 Importing customers.csv → Table: customers
# 📥 Importing staffs.csv → Table: staffs
# 📥 Importing orders.csv → Table: orders
# 📥 Importing stocks.csv → Table: stocks
# 📥 Importing order_items.csv → Table: order_items
# ✅ كل الملفات اتخزنت في MySQL بنجاح

# %% [markdown]
# # Way 2

# %%
import pandas as pd
import mysql.connector

# Set up the database connection
db_connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="bike_store"
)
cursor = db_connection.cursor()

# %%
# Function to import CSV data into a table
def import_csv_to_table(file_path, table_name):
    # Read the file
    df = pd.read_csv(file_path)
    
    # Replace NaN values with None (NULL for MySQL)
    df = df.where(pd.notnull(df), None)
    
    # Prepare SQL placeholders and columns
    placeholders = ', '.join(['%s'] * len(df.columns))
    columns = ', '.join([f"`{col}`" for col in df.columns])
    sql = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"
    # Insert data into the table
    for row in df.itertuples(index=False):
        clean_row = tuple(None if pd.isna(value) else value for value in row)
        cursor.execute(sql, clean_row)
    db_connection.commit()
    print(f"Data from {file_path} inserted into {table_name}")

# Import data files dynamically
try:
    csv_files = [
       "brands.csv",
        "categories.csv",
        "products.csv",
        "stores.csv",
        "customers.csv",
        "staffs.csv",
        "orders.csv",
        "stocks.csv",
        "order_items.csv"
    ]
    
    for file in csv_files:
        table_name = file.split(".")[0]  # Extract table name from filename
        import_csv_to_table(file, table_name)
finally:
    cursor.close()
    db_connection.close()
# Out:
# Data from brands.csv inserted into brands
# Data from categories.csv inserted into categories
# Data from products.csv inserted into products
# Data from stores.csv inserted into stores
# Data from customers.csv inserted into customers
# Data from staffs.csv inserted into staffs
# Data from orders.csv inserted into orders
# Data from stocks.csv inserted into stocks
# Data from order_items.csv inserted into order_items

# %%
pwd
# Out:
# 'C:\\Users\\Baraa\\Downloads\\Python SQL'

# %%
import os
os.chdir(r"C:\Users\Baraa\Downloads\archive")

# %%
df = pd.read_csv("customers.csv")
df
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks             NaN
# 1               2       Kasha      Todd             NaN
# 2               3      Tameka    Fisher             NaN
# 3               4       Daryl    Spence             NaN
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison             NaN
# 1441         1442      Cassie     Cline             NaN
# 1442         1443      Lezlie      Lamb             NaN
# 1443         1444      Ivette     Estes             NaN
# 1444         1445       Ester   Acevedo             NaN
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'phone', 'email', 'street',
#        'city', 'state', 'zip_code'],
#       dtype='object')

# %%
# Prepare SQL placeholders and columns
#  "INSERT INTO users (name, email) VALUES (%s, %s)"
columns = ', '.join([f"`{col}`" for col in df.columns])
columns
# Out:
# '`customer_id`, `first_name`, `last_name`, `phone`, `email`, `street`, `city`, `state`, `zip_code`'

# %%
table_name = "customers.csv".split(".")[0]
table_name
# Out:
# 'customers'

# %%
placeholders = ', '.join(['%s'] * len(df.columns))
placeholders
# Out:
# '%s, %s, %s, %s, %s, %s, %s, %s, %s'

# %%
sql = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"
sql
# Out:
# 'INSERT INTO customers (`customer_id`, `first_name`, `last_name`, `phone`, `email`, `street`, `city`, `state`, `zip_code`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)'

# %%
for row in df.itertuples(index=False):
    clean_row = tuple(None if pd.isna(value) else value for value in row)
    print(clean_row)
# Out:
# (1, 'Debra', 'Burks', None, 'debra.burks@yahoo.com', '9273 Thorne Ave. ', 'Orchard Park', 'NY', 14127)
# (2, 'Kasha', 'Todd', None, 'kasha.todd@yahoo.com', '910 Vine Street ', 'Campbell', 'CA', 95008)
# (3, 'Tameka', 'Fisher', None, 'tameka.fisher@aol.com', '769C Honey Creek St. ', 'Redondo Beach', 'CA', 90278)
# (4, 'Daryl', 'Spence', None, 'daryl.spence@aol.com', '988 Pearl Lane ', 'Uniondale', 'NY', 11553)
# (5, 'Charolette', 'Rice', '(916) 381-6003', 'charolette.rice@msn.com', '107 River Dr. ', 'Sacramento', 'CA', 95820)
# (6, 'Lyndsey', 'Bean', None, 'lyndsey.bean@hotmail.com', '769 West Road ', 'Fairport', 'NY', 14450)
# (7, 'Latasha', 'Hays', '(716) 986-3359', 'latasha.hays@hotmail.com', '7014 Manor Station Rd. ', 'Buffalo', 'NY', 14215)
# (8, 'Jacquline', 'Duncan', None, 'jacquline.duncan@yahoo.com', '15 Brown St. ', 'Jackson Heights', 'NY', 11372)
# (9, 'Genoveva', 'Baldwin', None, 'genoveva.baldwin@msn.com', '8550 Spruce Drive ', 'Port Washington', 'NY', 11050)
# ...

# %%
df = pd.read_csv("brands.csv", encoding="utf-8")
df
# Out:
#    brand_id    brand_name
# 0         1       Electra
# 1         2          Haro
# 2         3        Heller
# 3         4   Pure Cycles
# 4         5       Ritchey
# 5         6       Strider
# 6         7  Sun Bicycles
# 7         8         Surly
# 8         9          Trek
